# %% [markdown]
# # example48-1
# Solving the equations generated by node analysis for example48-1.net

# %%
from sympy import *
import numpy as np
init_printing()

# %% [markdown]
# copy the symbols used in nodal analysis

# %%
I_L1, s, I_V1, R3, R4, I_F1, R2, v3, v4, V2, ea1, I_V2, f1, v2, L1, V1, v1, I_Ea1, v5, I1 = symbols('I_L1 s I_V1 R3 R4 I_F1 R2 v3 v4 V2 ea1 I_V2 f1 v2 L1 V1 v1 I_Ea1 v5 I1')

# %% [markdown]
# copy the equation generated by nodal analysis

# %%
equ = Matrix([[Eq(I_L1 + I_V1 + v1/R2 - v2/R2, 0)], [Eq(I_F1 + v2*(1/R4 + 1/R2) - v5/R4 - v1/R2, 0)], [Eq(I_Ea1 - I_F1 + v3/R3 - v4/R3, 0)], [Eq(-I_L1 - v3/R3 + v4/R3, -I1)], [Eq(-I_V2 - v2/R4 + v5/R4, 0)], [Eq(v1, V1)], [Eq(-v5, V2)], [Eq(-ea1*v1 + ea1*v4 + v3, 0)], [Eq(I_F1 - I_V2*f1 + v2 - v3, 0)], [Eq(I_L1/(L1*s) + v1 - v4, 0)]])
equ
# Out:
# $$\left[\begin{matrix}I_{L1} + I_{V1} + \frac{v_{1}}{R_{2}} - \frac{v_{2}}{R_{2}} = 0\\I_{F1} + v_{2} \left(\frac{1}{R_{4}} + \frac{1}{R_{2}}\right) - \frac{v_{5}}{R_{4}} - \frac{v_{1}}{R_{2}} = 0\\I_{Ea1} - I_{F1} + \frac{v_{3}}{R_{3}} - \frac{v_{4}}{R_{3}} = 0\\- I_{L1} - \frac{v_{3}}{R_{3}} + \frac{v_{4}}{R_{3}} = - I_{1}\\- I_{V2} - \frac{v_{2}}{R_{4}} + \frac{v_{5}}{R_{4}} = 0\\v_{1} = V_{1}\\- v_{5} = V_{2}\\- ea_{1} v_{1} + ea_{1} v_{4} + v_{3} = 0\\I_{F1} - I_{V2} f_{1} + v_{2} - v_{3} = 0\\\frac{I_{L1}}{L_{1} s} + v_{1} - v_{4} = 0\end{matrix}\right]$$

# %%
# enter the element values
equ1a = equ.subs({L1:2})

equ1a = equ1a.subs({s:1e10})
#equ1a = equ1a.subs({I_L1:0})
#equ1a = equ1a.subs({v1:2})
#equ1a = equ1a.subs({v5:0})

equ1a = equ1a.subs({R2:1})
equ1a = equ1a.subs({R3:1})
equ1a = equ1a.subs({R4:2})

equ1a = equ1a.subs({V1:2})
equ1a = equ1a.subs({V2:0})
equ1a = equ1a.subs({I1:9})
equ1a = equ1a.subs({f1:2})
equ1a = equ1a.subs({ea1:2})

equ1a  # display the equations
# Out:
# $$\left[\begin{matrix}I_{L1} + I_{V1} + v_{1} - v_{2} = 0\\I_{F1} - v_{1} + \frac{3 v_{2}}{2} - \frac{v_{5}}{2} = 0\\I_{Ea1} - I_{F1} + v_{3} - v_{4} = 0\\- I_{L1} - v_{3} + v_{4} = -9\\- I_{V2} - \frac{v_{2}}{2} + \frac{v_{5}}{2} = 0\\v_{1} = 2\\- v_{5} = 0\\- 2 v_{1} + v_{3} + 2 v_{4} = 0\\I_{F1} - 2 I_{V2} + v_{2} - v_{3} = 0\\5.0 \cdot 10^{-11} I_{L1} + v_{1} - v_{4} = 0\end{matrix}\right]$$

# %%
str(solve(equ1a,[v1, v2, v3, v4, v5, I_V1, I_V2, I_Ea1, I_F1, I_L1]))
# Out:
# '{v1: 2.00000000000000, v4: 2.00000000055000, v3: -1.10000000016500e-9, I_F1: 8.00000000330000, I_V2: 2.00000000110000, I_V1: -17.0000000038500, v2: -4.00000000220000, I_Ea1: 10.0000000049500, v5: 0.0, I_L1: 11.0000000016500}'

# %%
str(solve(equ1a,[v1, v2, v3, v4, v5, I_V1, I_V2, I_Ea1, I_F1, I_L1]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-616fd778b0bb> in <module>()
# ----> 1 str(solve(equ1a,[v1, v2, v3, v4, v5, I_V1, I_V2, I_Ea1, I_F1, I_L1]))
#
# /ext/anaconda3/lib/python3.5/site-packages/sympy/solvers/solvers.py in solve(f, *symbols, **flags)
#     846             f[i] = fi.as_expr()
#     847         elif isinstance(fi, (bool, BooleanAtom)) or fi.is_Relational:
# --> 848             return reduce_inequalities(f, symbols=symbols)
#     849
#     850         # rewrite hyperbolics in terms of exp
#
# /ext/anaconda3/lib/python3.5/site-packages/sympy/solvers/inequalities.py in reduce_inequalities(inequalities, symbols)
#     669     if not iterable(symbols):
#     670         symbols = [symbols]
# --> 671     symbols = (set(symbols) or gens) & gens
#     672     if any(i.is_real is False for i in symbols):
#     673         raise TypeError(filldedent('''
#
# TypeError: unhashable type: 'list'

# %%
[v1, v2, v3, v4, v5, I_V1, I_V2, I_Ea1, I_F1, I_L1]
